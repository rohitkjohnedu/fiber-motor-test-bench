# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import plotly.express as px

# %%
filepath = "date_15-52-15_01-05-2026.csv"

# Find the line number of the actual header
with open(filepath) as f:
    for i, line in enumerate(f):
        if line.strip().startswith("state"):
            header_row = i
            break

df = pd.read_csv(filepath, skiprows=header_row, skipinitialspace=True, na_values=["-"])
